# %%
import pandas as pd
import numpy as np
import torch 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split
import glob, os, pickle
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from torch import nn
from matplotlib import cm

# %%
import PIL 
from PIL import Image as im
from IPython.display import Image

# %%
PIL.Image.MAX_IMAGE_PIXELS = 1985009480

# %%
image = im.open("/dartfs/rc/nosnapshots/V/VaickusL-nb/EDIT_Students/projects/scc_nuclei/data/281_A1f_ASAP.tif")

# %%
width, height = image.size

# %%
print(width, height)
# Out:
# 65320 30389

# %%
new_image = image.resize((int(width/40), int(height/40))) # make the image smaller and easier to display

# %%
width, height = new_image.size
print(width, height)
# Out:
# 1633 759

# %%
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1633x759>
